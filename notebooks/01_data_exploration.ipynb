# %% [markdown]
# # Data Exploration
#
# Inspect channel names and simple statistics of the dummy dataset.

# %%
import numpy as np
from eegintent.data.loaders import load_dummy_dataset
ds = load_dummy_dataset(n_samples=16, n_channels=8, n_times=128)
ds.ch_names, ds.X.shape, ds.y.shape

# %%
# Show per-channel mean/std
ds.X.mean(axis=(0,2)), ds.X.std(axis=(0,2))
